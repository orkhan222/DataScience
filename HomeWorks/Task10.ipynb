# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
import pandas as pd
data = pd.read_csv(r"../Datasets/public_transportation_data.csv")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 data = pd.read_csv(r"../Datasets/public_transportation_data.csv")
#       3 data
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
country_counts = data['destination'].value_counts()

# Display the countries and their visit counts
print(country_counts)
# Out:
# MADRID        1220348
# BARCELONA      480074
# SEVILLA        413155
# VALENCIA       399679
# PONFERRADA      66515
# Name: destination, dtype: int64

# %%
date_counts = data['insert_date'].value_counts()

# Display the date
print(date_counts)
# Out:
# 2019-05-09 15:02:02    121
# 2019-04-14 13:04:07    120
# 2019-04-15 03:05:42    120
# 2019-04-19 20:03:12    120
# 2019-04-29 23:15:13    119
#                       ...
# 2019-05-01 13:44:10      1
# 2019-05-01 13:44:07      1
# 2019-05-01 13:44:03      1
# 2019-05-01 13:43:56      1
# 2019-04-22 08:02:47      1
# Name: insert_date, Length: 145107, dtype: int64

# %%
country_counts = data['origin'].value_counts()

# Create a bar chart to visualize the visit counts
plt.figure(figsize=(10, 6))
country_counts.plot(kind='bar', color='skyblue')
plt.title('Train Visits by Country')
plt.xlabel('origin')
plt.ylabel('Number of Visits')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()

# Display the chart
plt.show()

# %%
train_class_price_mean = data.groupby('train_class')['price'].mean()

# Display the average price for each train class
print(train_class_price_mean)
# Out:
# train_class
# Cama G. Clase         150.600000
# Cama Turista           74.200000
# Preferente             82.166511
# Turista                60.692947
# Turista Plus           83.026825
# Turista con enlace     43.641727
# Name: price, dtype: float64

# %%
df = pd.read_csv('/content/public_transportation_data.csv')

df['start_date'] = pd.to_datetime(df['start_date'])
df['end_date'] = pd.to_datetime(df['end_date'])

# Calculate the duration for each row
df['duration'] = (df['end_date'] - df['start_date']).dt.total_seconds() / 3600  # Duration in hours

# Find the destination with the longest duration
longest_destination = df.loc[df['duration'].idxmax()]

print(f"The destination that took the longest time is '{longest_destination['destination']}' with a duration of {longest_destination['duration']:.2f} hours.")
# Out:
# The destination that took the longest time is 'MADRID' with a duration of 12.42 hours.

# %%
# Create a count plot to visualize the popularity of train types
plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
sns.countplot(data=data, x='train_type')
plt.title('Popularity of Train Types')
plt.xlabel('Train Type')
plt.ylabel('Count')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=45)

# Display the chart
plt.show()
