# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
data = pd.read_csv("/content/public_transportation_data.csv")
data
# Out:
#        Unnamed: 0          insert_date  origin destination  \
# 0               0  2019-04-19 05:31:43  MADRID     SEVILLA
# 1               1  2019-04-19 05:31:43  MADRID     SEVILLA
# 2               2  2019-04-19 05:31:43  MADRID     SEVILLA
# 3               3  2019-04-19 05:31:43  MADRID     SEVILLA
# 4               4  2019-04-19 05:31:43  MADRID     SEVILLA
# ...           ...                  ...     ...         ...
# 67487       67487  2019-04-19 17:31:30  MADRID   BARCELONA
# 67488       67488  2019-04-19 17:31:30  MADRID   BARCELONA
# 67489       67489  2019-04-19 17:31:30  MADRID   BARCELONA
# 67490       67490  2019-04-19 17:31:30  MADRID   BARCELONA
# 67491       67491  2019-04-19 17:31:30  MADRID   BARCELONA
#
#                 start_date             end_date train_type   price  \
# 0      2019-05-29 06:20:00  2019-05-29 09:16:00    AV City   38.55
# 1      2019-05-29 07:00:00  2019-05-29 09:32:00        AVE   53.40
# ...

# %%
country_counts = data['destination'].value_counts()

# Display the countries and their visit counts
print(country_counts)
# Out:
# MADRID        33345
# BARCELONA     11390
# VALENCIA      10797
# SEVILLA        9996
# PONFERRADA     1964
# Name: destination, dtype: int64

# %%
date_counts = data['insert_date'].value_counts()

# Display the date
print(date_counts)
# Out:
# 2019-04-19 17:19:34    92
# 2019-04-19 07:02:03    90
# 2019-04-19 16:00:31    79
# 2019-04-19 14:00:50    79
# 2019-04-19 10:00:28    74
#                        ..
# 2019-04-19 07:25:06     1
# 2019-04-19 10:32:02     1
# 2019-04-19 10:31:57     1
# 2019-04-19 10:31:55     1
# 2019-04-19 15:40:33     1
# Name: insert_date, Length: 3997, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file
data = pd.read_csv("/content/public_transportation_data.csv")

# Assuming you have a column named "Country" in your DataFrame
country_counts = data['origin'].value_counts()

# Create a bar chart to visualize the visit counts
plt.figure(figsize=(10, 6))
country_counts.plot(kind='bar', color='skyblue')
plt.title('Train Visits by Country')
plt.xlabel('origin')
plt.ylabel('Number of Visits')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()

# Display the chart
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv("/content/public_transportation_data.csv")

# Assuming you have columns "Country" and "Train Type" in your DataFrame
# Group the data by both Country and Train Type and count the occurrences
grouped_data = data.groupby(['origin', 'train type']).size().unstack(fill_value=0)

# Create a grouped bar chart to visualize the train visits by country and train type
plt.figure(figsize=(12, 6))
sns.heatmap(grouped_data, cmap='Blues', annot=True, fmt='d')
plt.title('Train Visits by Country and Train Type')
plt.xlabel('Train Type')
plt.ylabel('Country')

# Display the chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-5a6bc65354ac> in <cell line: 10>()
#       8 # Assuming you have columns "Country" and "Train Type" in your DataFrame
#       9 # Group the data by both Country and Train Type and count the occurrences
# ---> 10 grouped_data = data.groupby(['origin', 'train type']).size().unstack(fill_value=0)
#      11
#      12 # Create a grouped bar chart to visualize the train visits by country and train type
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8400         axis = self._get_axis_number(axis)
#    8401
# -> 8402         return DataFrameGroupBy(
#    8403             obj=self,
#    8404             keys=by,
#
# ...

# %%
import pandas as pd

# Load the data from the CSV file
data = pd.read_csv("/content/public_transportation_data.csv")

# Calculate the correlation between numeric columns
correlation_matrix = data.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#             Unnamed: 0     price
# Unnamed: 0    1.000000 -0.008255
# price        -0.008255  1.000000
# <ipython-input-20-2d6cd0cf7848>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'insert_date', 'origin', 'destination', 'start_date',
#        'end_date', 'train_type', 'price', 'train_class', 'fare'],
#       dtype='object')

# %%
import pandas as pd

# Load the data from the CSV file
data = pd.read_csv("/content/public_transportation_data.csv")

# Group the data by 'train_class' and calculate the mean price for each class
train_class_price_mean = data.groupby('train_class')['price'].mean()

# Display the average price for each train class
print(train_class_price_mean)
# Out:
# train_class
# Cama G. Clase         150.600000
# Cama Turista           74.200000
# Preferente             82.215016
# Turista                60.359329
# Turista Plus           83.352395
# Turista con enlace     43.921605
# Name: price, dtype: float64
